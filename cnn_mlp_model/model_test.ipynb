# %%
import numpy as np
import matplotlib.pyplot as plt

import sys
import os
sys.path.append(os.getcwd())

from train_cnn_mlp import preload_hdf5_to_memory

import matplotlib as mpl
mpl.rcParams.update({
    "font.family": "serif",
    "font.serif": ["TeX Gyre Pagella", "Book Antiqua", "Palatino Linotype", "DejaVu Serif"]
})

import pickle
import jax
import jax.numpy as jnp

from cnn_mlp_model import CNNMLPModel, ModelConfig

print(jax.devices())
print("default backend:", jax.default_backend())

# %% [markdown]
# ### Import data

# %%
test_path = '/projects/mccleary_group/habjan.e/TNG/Data/CNN_MLP_data/CNN_MLP_test.h5'
train_path = '/projects/mccleary_group/habjan.e/TNG/Data/CNN_MLP_data/CNN_MLP_train.h5'

data_dict = preload_hdf5_to_memory(test_path)

data_im, data_gal, data_pix, data_tar, data_mask = data_dict['images'], data_dict['gal_features'], data_dict['gal_pixel_coords'], data_dict['targets'], data_dict['mask']

# %% [markdown]
# ### Plot data

# %%
test_idx = 900

imgs = data_im[test_idx, :, :, :]
cmap = 'cubehelix'

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 10), constrained_layout=True)
fig.set_constrained_layout_pads(w_pad=0.2, h_pad=0.2, wspace=0.1, hspace=0.1)
ax1, ax2, ax3 = axes[0], axes[1], axes[2]

im1 = ax1.imshow(imgs[0], vmin = np.quantile(imgs[0], 0.5), vmax = np.quantile(imgs[0], 0.98), cmap=cmap, origin="upper")
ax1.set_xlabel("X-coordinate", fontsize=14, fontweight='semibold')
ax1.set_ylabel("Y-coordinate", fontsize=14, fontweight='semibold')
cbar = fig.colorbar(im1, ax=ax1, fraction=0.046, pad=0.02)
cbar.set_label("Projected Mass", fontsize=14, fontweight='semibold')

im2 = ax2.imshow(imgs[1], cmap=cmap, origin="upper")
ax2.set_xlabel("X-coordinate", fontsize=14, fontweight='semibold')
ax2.set_ylabel("Y-coordinate", fontsize=14, fontweight='semibold')
cbar = fig.colorbar(im2, ax=ax2, fraction=0.046, pad=0.02)
cbar.set_label("Galaxy Density", fontsize=14, fontweight='semibold')

im3 = ax3.imshow(imgs[2], cmap=cmap, origin="upper")
ax3.set_xlabel("X-coordinate", fontsize=14, fontweight='semibold')
ax3.set_ylabel("Y-coordinate", fontsize=14, fontweight='semibold')
cbar = fig.colorbar(im3, ax=ax3, fraction=0.046, pad=0.02)
cbar.set_label("$\mathbf{V_{z}}$", fontsize=14, fontweight='semibold')

fig.savefig("/home/habjan.e/TNG/cluster_deprojection/figures/cnnmlp_data.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Import model parameters and build model object

# %%
params_path = "/home/habjan.e/TNG/cluster_deprojection/cnn_mlp_model/CNN_MLP_models/cnn_mlp_params_cnnmlp_5by5.pkl"
with open(params_path, "rb") as f:
    params = pickle.load(f)


cfg = ModelConfig(
        smoother_kernel=5,
        fmap_channels=(32, 64, 128),
        fmap_blocks_per_stage=2,
        cnn_dropout=0.0,
        sampler_window=5,
        mlp_hidden=(128, 128),
        head_hidden=(256, 256),
        dropout=0.0,
        output_dim=1,
        )

model = CNNMLPModel(cfg=cfg)

# %% [markdown]
# ### Valid galaxies in test dataset

# %%
valid = np.argwhere(data_dict["mask"] > 0.5)
print("valid galaxies:", len(valid))

# %% [markdown]
# ### Randomly select a subset of galaxies

# %%
gal_num = 100

rng = np.random.default_rng(0)
K = min(gal_num, len(valid))
sel = valid[rng.choice(len(valid), size=K, replace=False)]
s_idx = sel[:, 0]
n_idx = sel[:, 1]

# %% [markdown]
# ### preprocess data

# %%
images = data_dict["images"][s_idx]              # (B,C,H,W)
images = np.transpose(images, (0, 2, 3, 1))      # (B,H,W,C)

mlp_in = data_dict["gal_features"][s_idx, n_idx]       # (B,F)
pix = data_dict["gal_pixel_coords"][s_idx, n_idx]      # (B,2)
targets = data_dict["targets"][s_idx, n_idx]

mlp_in = mlp_in[:, None, :]
pix = pix[:, None, :]
targets = targets[:, None, :]

images_j = jnp.asarray(images)
mlp_j = jnp.asarray(mlp_in)
pix_j = jnp.asarray(pix)
targ_j = jnp.asarray(targets)

# %% [markdown]
# ### Forward pass

# %%
preds = model.apply({"params": params}, images_j, mlp_j, pix_j, deterministic=True)
preds = np.array(preds)     # (B,1,D)
targs = np.array(targ_j)    # (B,1,D)

preds = preds[:, 0, :]
targs = targs[:, 0, :]

# %% [markdown]
# ### Statistics

# %%
print("preds shape:", preds.shape, "targets shape:", targs.shape)

# -------- metrics ----------
res = preds - targs
mse = np.mean(np.sum(res**2, axis=-1))
mae = np.mean(np.abs(res), axis=0)
rmse = np.sqrt(np.mean(res**2, axis=0))

print("MSE (sum over dims):", mse)
print("MAE per-dim:", mae)
print("RMSE per-dim:", rmse)

# R^2 per dimension
tvar = np.var(targs, axis=0) + 1e-12
r2 = 1.0 - np.mean((preds - targs)**2, axis=0) / tvar
print("R2 per-dim:", r2)

# %% [markdown]
# ### Plot results

# %%
fig, axs = plt.subplots(1, 1, figsize=(6, 5), gridspec_kw={'wspace': 0.35})

one_one = np.linspace(-5, 15, 100)

x_plot_pos, y_plot_pos = (targs*1.25) + 1.25, (preds*1.25) + 1.25

axs.scatter(x_plot_pos, y_plot_pos, c='k', s=10)
axs.plot(one_one, one_one, c='k', linestyle='--')
axs.set_xlabel(r'BAHAMAS $|z|$-position $\left[ Mpc \right]$', fontsize = 15)
axs.set_ylabel(r'CNN-MLP $|z|$-position $\left[ Mpc \right]$', fontsize = 15)
lims = np.concatenate([x_plot_pos, y_plot_pos])
axs.set_xlim(-0.1, np.max(lims)*1.1)
axs.set_ylim(-0.1, np.max(lims)*1.1)
